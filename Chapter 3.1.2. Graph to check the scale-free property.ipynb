# %% [markdown]
# # Scale-free property checking
# In this notebook the graph described in the section Theretical Background- Scale-Free property is created.

# %%
# %store -r G 
import networkx as nx
import matplotlib.pyplot as plt
import random
import statistics
import pandas as pd
import seaborn as sns
from sklearn.model_selection import train_test_split 
from sklearn.linear_model import LinearRegression
from sklearn import metrics
import math
import numpy as np

# %%
ks=[]
for i in list(G.nodes):
    ks.append(G.nodes[i]['k'])

# %%
n, bins, patches=plt.hist(ks,bins=50)#,density=True,stacked=True)
n=list(n)
n.append(1)
p_k=[np.log(i/92) for i in n]
k_value=[np.log(i) for i in bins]
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: RuntimeWarning: divide by zero encountered in log
#   after removing the cwd from sys.path.

# %%
f=23
plt.figure(figsize=(10,10)) 
plt.scatter(k_value,p_k,color='red')
plt.plot(k_value,p_k)
#plt.title('ten wykres z książki, czy spełnia to power law')
plt.ylabel('log(p_k)',fontsize=f)
plt.xlabel('log(k)',fontsize=f)
plt.xticks(fontsize=f)
plt.yticks(fontsize=f)

a=plt.gcf()
a.savefig("C:/Users/wojci/Documents/Studia/praca/ZDEJCIA/rozdzial2/"+"scale_free"+".eps")
plt.show()

# %% [markdown]
# Scale free property is not evident
